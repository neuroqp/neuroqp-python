# %% [markdown]
# # Validate an export
#
# Validation returns every metadata issue it can safely identify in one report.

# %%
from pathlib import Path

from neuroqp import validate_export

sample = Path("../assets/downloads/neuroqp-example-v2.zip")
report = validate_export(sample)
report

# %%
assert report.valid
assert report.issues == ()
